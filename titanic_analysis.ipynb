# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age']=df['Age'].fillna(29)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age']=df['Age'].astype(int)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Embarked'].hist()
# Out:
# <Axes: >

# %%
sns.barplot(x='Embarked',y='Age',data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='Age'>

# %%
sns.barplot(x='Survived',y='Pclass',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
df['Survived'].hist()
# Out:
# <Axes: >

# %%
df=df.drop(['Cabin','Ticket'],axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch     Fare Embarked
# 0      0   7.2500        S
# 1      0  71.2833        C
# 2      0   7.9250        S
# 3      0  53.1000        S
# 4      0   8.0500        S

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df[df['Name'].str.contains('Allen')]
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 4              5         0       3       Allen, Mr. William Henry    male
# 730          731         1       1  Allen, Miss. Elisabeth Walton  female
#
#      Age  SibSp  Parch      Fare Embarked
# 4     35      0      0    8.0500        S
# 730   29      0      0  211.3375        S

# %%
df[['Name', 'Family_member']]=df['Name'].str.split(',',expand=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass       Name     Sex  Age  SibSp  Parch  \
# 0            1         0       3     Braund    male   22      1      0
# 1            2         1       1    Cumings  female   38      1      0
# 2            3         1       3  Heikkinen  female   26      0      0
# 3            4         1       1   Futrelle  female   35      1      0
# 4            5         0       3      Allen    male   35      0      0
#
#       Fare Embarked                                Family_member
# 0   7.2500        S                              Mr. Owen Harris
# 1  71.2833        C   Mrs. John Bradley (Florence Briggs Thayer)
# 2   7.9250        S                                  Miss. Laina
# 3  53.1000        S           Mrs. Jacques Heath (Lily May Peel)
# 4   8.0500        S                            Mr. William Henry

# %%
df['Gender']=df['Sex'].map({'male':1,'female':0})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass       Name     Sex  Age  SibSp  Parch  \
# 0            1         0       3     Braund    male   22      1      0
# 1            2         1       1    Cumings  female   38      1      0
# 2            3         1       3  Heikkinen  female   26      0      0
# 3            4         1       1   Futrelle  female   35      1      0
# 4            5         0       3      Allen    male   35      0      0
#
#       Fare Embarked                                Family_member  Gender
# 0   7.2500        S                              Mr. Owen Harris       1
# 1  71.2833        C   Mrs. John Bradley (Florence Briggs Thayer)       0
# 2   7.9250        S                                  Miss. Laina       0
# 3  53.1000        S           Mrs. Jacques Heath (Lily May Peel)       0
# 4   8.0500        S                            Mr. William Henry       1

# %%
df=df.drop("Sex",axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass       Name  Age  SibSp  Parch     Fare  \
# 0            1         0       3     Braund   22      1      0   7.2500
# 1            2         1       1    Cumings   38      1      0  71.2833
# 2            3         1       3  Heikkinen   26      0      0   7.9250
# 3            4         1       1   Futrelle   35      1      0  53.1000
# 4            5         0       3      Allen   35      0      0   8.0500
#
#   Embarked                                Family_member  Gender
# 0        S                              Mr. Owen Harris       1
# 1        C   Mrs. John Bradley (Florence Briggs Thayer)       0
# 2        S                                  Miss. Laina       0
# 3        S           Mrs. Jacques Heath (Lily May Peel)       0
# 4        S                            Mr. William Henry       1

# %%
sns.countplot(x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.barplot(x='Pclass',y='Age',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
#how many people survived and how many people are died
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>
